# %% [markdown]
# ## EDA using Snowflake & Deepnote on Aircraft ✈️

# %% [markdown]
# * L'objectif de ce projet est d'utiliser Deepnote pour effectuer :
# * Une analyse exploratoire des données EDA sur les données aéronautiques chargées dans SNOWFLAKE

# %%
pip install --upgrade snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in c:\users\steph\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=44.0.1 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (44.0.1)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=24.0.0 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (25.0.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (2.32.5)
# Requirement already satisfied: packaging in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=3.7 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (2025.11.12)
# Requirement already satisfied: typing_extensions<5,>=4.3 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (4.12.2)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (3.17.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (4.3.7)
# Requirement already satisfied: tomlkit in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (0.13.2)
# Requirement already satisfied: boto3>=1.24 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (1.36.3)
# Requirement already satisfied: botocore>=1.24 in c:\users\steph\anaconda3\lib\site-packages (from snowflake-connector-python) (1.36.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\steph\anaconda3\lib\site-packages (from cryptography>=44.0.1->snowflake-connector-python) (1.17.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\steph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.4->snowflake-connector-python) (2.3.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\steph\anaconda3\lib\site-packages (from boto3>=1.24->snowflake-connector-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\steph\anaconda3\lib\site-packages (from boto3>=1.24->snowflake-connector-python) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\steph\anaconda3\lib\site-packages (from botocore>=1.24->snowflake-connector-python) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\steph\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.24->snowflake-connector-python) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\steph\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=44.0.1->snowflake-connector-python) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * Connection à SNOWFLAKE et import des différentes librairies

# %%
import snowflake.connector
from dotenv import load_dotenv
import os
import pandas as pd 
import seaborn as sns 
import plotly.express as px 
import matplotlib.pyplot as plt

# %%
load_dotenv()
# Out:
# True

# %%
snow_password = os.environ["SNOWFLAKE_PASSWORD"] 
snow_login = os.environ["SNOWFLAKE_LOGIN"]

conn = snowflake.connector.connect(
    user="SBRETTON",
    password=snow_password,
    account=snow_login
)

# %% [markdown]
# * Connexion à ma Database "ANALYTICS" sur SNOWFLAKE

# %%
 # DATABASE ANALYTICS pour accéder à nos modèles dans Snowflake
conn.cursor().execute("USE DATABASE ANALYTICS")
conn.cursor().execute("USE SCHEMA DBT_SBRETTON") #schema

# %% [markdown]
# * Import de mes views staging

# %%
# staging AIRCRAFT
stg_aircraft = conn.cursor().execute("SELECT * FROM stg_aircraft").fetch_pandas_all()
stg_aircraft.head()
# Out:
#   AIRCRAFT_ID AIRCRAFT_TYPE  CAPACITY        COST  LENGTH     MASS
# 0         12d   Flockinator      1000   100000000   10000  1000000
# 1         12a     Miniflock       200     2000000    2000    50000
# 2         g72         Goose       500     3000000    5000   200000
# 3         t10    Thundercat      2000   400000000   20000  1500000
# 4         b23     Bezantium      5000  1000000000  100000  4000000

# %%
# staging AIRLINES 
stg_airlines = conn.cursor().execute("SELECT * FROM stg_airlines").fetch_pandas_all()
stg_airlines.head()
# Out:
#   AIRLINE_CODE     AIRLINE_NAME  \
# 0           FA        Flock Air
# 1           GA    Goose Airways
# 2           AA  Amazon Airlines
#
#                                          DESCRIPTION  MARKET_CAP  EMPLOYEES  \
# 0  The most innovative and groundbreaking airline...  1000000000    2000000
# 1  Caters only for the needs of their exclusive c...    50000000      30000
# 2  Controlled from the mothership by Jeff Bezos h...  2000000000   10000000
#
#    AGE
# 0   10
# 1    6
# 2   22

# %%
# staging AIRPORTS
stg_airports = conn.cursor().execute("SELECT * FROM stg_airports").fetch_pandas_all()
stg_airports.head()
# Out:
#   AIRPORT_CODE       AIRPORT_NAME  AIRPORT_EMPLOYEES  AIRPORT_SIZE
# 0          FKT         Flocktopia            1000000       2000000
# 1          NSA   Nestland Airport              20000         50000
# 2          AMP  Amazon Mothership             100000         10000

# %%
# staging FLIGHT_SUMMARY_DATA
stg_flight_summary_data = conn.cursor().execute("SELECT * FROM stg_flight_summary_data").fetch_pandas_all()
stg_flight_summary_data.head()
# Out:
#    index        DATE  ASM_DOMESTIC  ASM_INTERNATIONAL  FLIGHTS_DOMESTIC  \
# 0      0  2002-10-01         59854                0.0               774
# 1      1  2002-11-01         55009                0.0               733
# 2      2  2002-12-01         56586                0.0               745
# 3      3  2003-01-01         57448                0.0               754
# 4      4  2003-02-01         54006                0.0               674
#
#    FLIGHTS_INTERNATIONAL  PASSENGERS_DOMESTIC  PASSENGERS_INTERNATIONAL  \
# 0                    0.0                60464                      59.0
# 1                    0.0                57649                       0.0
# 2                    0.0                66240                       0.0
# 3                    0.0                55317                       4.0
# 4                    0.0                53216                      65.0
#
#    RPM_DOMESTIC  RPM_INTERNATIONAL AIRLINE_CODE AIRPORT_CODE
# 0         38363                0.0           FA          FKT
# 1         36286                0.0           FA          FKT
# 2         41907                0.0           FA          FKT
# 3         35118                0.0           FA          FKT
# 4         33724                0.0           FA          FKT

# %%
# staging INDIVIDUAL_FLIGHTS
stg_individual_flights = conn.cursor().execute("SELECT * FROM stg_individual_flights").fetch_pandas_all()
stg_individual_flights.head()
# Out:
#   AIRCRAFT_ID AIRLINE_CODE DEPARTURE_AIRPORT_CODE DESTINATION_AIRPORT_CODE  \
# 0         12d           FA                    FKT                      NSA
# 1         12d           FA                    FKT                      NSA
# 2         12d           FA                    FKT                      NSA
# 3         12d           FA                    FKT                      NSA
# 4         12d           FA                    FKT                      NSA
#
#    FLIGHT_ID
# 0     100001
# 1     100002
# 2     100003
# 3     100004
# 4     100005

# %% [markdown]
# * Import de mes tables de dimensions

# %%
dim_aircraft = conn.cursor().execute("SELECT * FROM dim_aircraft").fetch_pandas_all()
dim_airlines = conn.cursor().execute("SELECT * FROM dim_airlines").fetch_pandas_all()
dim_airports = conn.cursor().execute("SELECT * FROM dim_airports").fetch_pandas_all()
dim_flight_summary_data = conn.cursor().execute("SELECT * FROM dim_flight_summary_data").fetch_pandas_all()
dim_individual_flights = conn.cursor().execute("SELECT * FROM dim_individual_flights").fetch_pandas_all()

# %% [markdown]
# # 1- Quelle appareil a effectué le plus de vols ?

# %% [markdown]
# ## Import de la fct_number_of_flights

# %%
# fct NUMBER_OF_FLIGHTS
fct_number_of_flights = conn.cursor().execute("SELECT * FROM fct_number_of_flights").fetch_pandas_all()
fct_number_of_flights.head()
# Out:
#   AIRCRAFT_TYPE AIRCRAFT_ID  NUMBER_OF_FLIGHTS
# 0         Goose         g72               1008
# 1    Thundercat         t10                553
# 2     Miniflock         12a                277
# 3     Bezantium         b23                240
# 4   Flockinator         12d                192

# %%
sizes = fct_number_of_flights["NUMBER_OF_FLIGHTS"]
labels = fct_number_of_flights["AIRCRAFT_TYPE"]

# %%
plt.figure(figsize=(10, 8))

plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Distribution des vols par type d\'avion')

plt.show()

# %% [markdown]
# * L'appareil GOOSE assure la majorité des vols avec 44%

# %%
sns.barplot(data=fct_number_of_flights,
            x= "AIRCRAFT_TYPE",
            y= "NUMBER_OF_FLIGHTS")

plt.xlabel("Type d'appareil (AIRCRAFT_TYPE)")
plt.ylabel("Nombre de vols (NUMBER_OF_FLIGHTS)")

plt.tight_layout() 
plt.show()

# %% [markdown]
# ## 2- Quel aéroport a été le plus emprunté par les passagers ?

# %% [markdown]
# * Import de la fct_airports

# %%
# Import de la fct_airports
fct_airports = fct_airports = conn.cursor().execute("SELECT * FROM fct_airports").fetch_pandas_all()
fct_airports.head()
# Out:
#   AIRPORT_CODE       AIRPORT_NAME  PASSENGERS_NB
# 0          FKT         Flocktopia    430959170.0
# 1          NSA   Nestland Airport    179064722.0
# 2          AMP  Amazon Mothership     80033991.0

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    data=fct_airports,
    x="AIRPORT_NAME",
    y="PASSENGERS_NB",
    palette="viridis" 
)

plt.title('Aéroport ayant transporté le plus de passagers')

plt.xlabel("Aéroport (AIRPORT_NAME)")
plt.ylabel("Total passagers (Sum of passengers_nb)")

for index, row in fct_airports.iterrows():
    plt.text(
        index,                  # Position X (index de la barre)
        row["PASSENGERS_NB"],   # Position Y (hauteur de la barre)
        f'{row["PASSENGERS_NB"]:,}', # Texte à afficher
        color='black',
        ha="center",            # Alignement horizontal
        va="bottom"             # Alignement vertical (en haut de la barre)
    )

plt.xticks(rotation=45, ha='right')

plt.tight_layout() 
plt.show()
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_20916\3284093973.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# * L'aéroport FLOCKTOPIA à lui seul a accueilli plus de passagers que les 2 autres réunis

# %% [markdown]
# ## 3- Quelle a été la meilleure année en termes de recettes par psg/km pour chaque compagnie aérienne ?

# %% [markdown]
# * Import de la fct_airlines

# %%
# Import de la fct_airlines
fct_airlines = fct_airlines = conn.cursor().execute("SELECT * FROM fct_airlines").fetch_pandas_all()
fct_airlines.head()
# Out:
#   AIRLINE_CODE     AIRLINE_NAME  YEAR  MAX_REVENUE              METRIQUE
# 0           AA  Amazon Airlines  2015    9175044.0     Revenu Domestique
# 1           FA        Flock Air  2016   13405774.0     Revenu Domestique
# 2           GA    Goose Airways  2016   34637841.0     Revenu Domestique
# 3           AA  Amazon Airlines  2016    2792855.0  Revenu International
# 4           FA        Flock Air  2016    3912894.0  Revenu International

# %%
plt.figure(figsize=(14, 8))

ax = sns.barplot(
    data=fct_airlines,
    x="AIRLINE_NAME",
    y="MAX_REVENUE",
    hue="METRIQUE", 
    palette="deep" 
)

plt.title('MAX_REVENUE par Compagnie Aérienne et Métrique', fontsize=16)
plt.xlabel("Compagnie Aérienne (AIRLINE_NAME)")
plt.ylabel("Revenu Maximal (MAX_REVENUE)")
plt.xticks(rotation=45, ha='right')
plt.legend(title="METRIQUE")


for i, p in enumerate(ax.patches):
    try:
        
        year_label = fct_airlines['YEAR'].iloc[i] 
        
        ax.annotate(
            f"{year_label}",           
            (p.get_x() + p.get_width() / 2., p.get_height()), 
            ha='center', va='center',  
            xytext=(0, 10),            
            textcoords='offset points',
            fontsize=9
        )
    except IndexError:
        pass 


plt.tight_layout() 
plt.show()

# %% [markdown]
# * Le revenu Domestique constitue pour chaque compagnie l'essentiel du revenu total.
# * La meilleure année est 2015 pour Amazon Airlines, 2016 pour Flock_Air et Goose_Airways.

# %% [markdown]
# ## 4- Quelle a été la meilleure année en termes de croissance pour chaque compagnie aérienne ?

# %% [markdown]
# * Import de la fct_croissance_per_year

# %%
# Import de la fct_croissance_per_year
fct_croissance_per_year = fct_croissance_per_year = conn.cursor().execute("SELECT * FROM fct_croissance_per_year").fetch_pandas_all()
fct_croissance_per_year.head()
# Out:
#   AIRLINE_CODE     AIRLINE_NAME  YEAR  AVG_ASM_DOMESTIC  PREVIOUS_YEAR  \
# 0           AA  Amazon Airlines  2002     315931.000000            NaN
# 1           AA  Amazon Airlines  2003     295645.527778  315931.000000
# 2           AA  Amazon Airlines  2004     296641.388889  295645.527778
# 3           AA  Amazon Airlines  2005     255289.083333  296641.388889
# 4           AA  Amazon Airlines  2006     270788.361111  255289.083333
#
#    TAUX_CROISSANCE
# 0              NaN
# 1            -6.42
# 2             0.34
# 3           -13.94
# 4             6.07

# %% [markdown]
# ### Evolution annuelle de l'ASM moyen par compagnie aérienne

# %%
plt.figure(figsize=(12, 6))

sns.lineplot(
    data=fct_croissance_per_year,
    x="YEAR",
    y="AVG_ASM_DOMESTIC",
    hue="AIRLINE_NAME",  
    marker="o"           # Ajout marqueur à chaque point de données 
)

plt.title("Évolution annuelle de l'ASM moyen par compagnie aérienne", fontsize=16)

plt.xlabel("Année (YEAR)")
plt.ylabel("ASM Moyen Domestique (AVG_ASM_DOMESTIC)")

plt.legend(title='Compagnie Aérienne', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xticks(fct_croissance_per_year['YEAR'].unique())

plt.tight_layout() 
plt.show()

# %% [markdown]
# * L'évolution de l'ASM moyen est assez stable pour Flock_Air et Amazon_Airlines.
# * L'ASM moyen évolue de façon positive, bien que faiblement pour Goose_Airways.

# %% [markdown]
# ### Evolution du taux de croissance annuel par compagnies aériennes

# %%
plt.figure(figsize=(12, 6))

ax = sns.lineplot(
    data=fct_croissance_per_year,
    x="YEAR",
    y="TAUX_CROISSANCE",
    hue="AIRLINE_NAME",  
    marker="o"           
)

plt.title("Taux de croissance annuel par compagnies aériennes", fontsize=16)

plt.xlabel("Année (YEAR)")
plt.ylabel("Taux de Croissance (TAUX_CROISSANCE)")

plt.legend(title='Compagnie Aérienne', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xticks(fct_croissance_per_year['YEAR'].unique())

plt.tight_layout() 
plt.show()

# %% [markdown]
# * Le taux de croissance est faible et souvent négatif entre 2003 et 2009.
# * Des pics soudain apparaissent à partir de 2010 avec :
# * - Un taux de croissance de 20.67 pour Goose_Airways en 2010.
# * - Un taux de croissance de 46.02 pour Amazon_Airlines en 2012.
# * - Un taux de croissance de 16.04 pour Flock_Air en 2016.

# %% [markdown]
# ### Année du meilleur taux de croissance

# %% [markdown]
# * Import de la fct_croissance

# %%
# Import de la fct_croissance
fct_croissance = fct_croissance = conn.cursor().execute("SELECT * FROM fct_croissance").fetch_pandas_all()
fct_croissance.head()
# Out:
#   AIRLINE_CODE     AIRLINE_NAME  BEST_YEAR  BEST_TAUX_CROISSANCE
# 0           AA  Amazon Airlines       2012                 46.02
# 1           FA        Flock Air       2016                 16.04
# 2           GA    Goose Airways       2010                 20.67

# %%
plt.figure(figsize=(12, 7))

ax = sns.barplot(
    data=fct_croissance,
    x="AIRLINE_NAME",
    y="BEST_TAUX_CROISSANCE",
    hue="BEST_YEAR",  
    dodge=False,      
    palette="viridis" 
)

plt.title("Année du taux de croissance le plus élevé", fontsize=16)

plt.xlabel("Compagnie Aérienne (AIRLINE_NAME)")
plt.ylabel("Meilleur Taux de Croissance (BEST_TAUX_CROISSANCE)")

plt.xticks(rotation=45, ha='right')

plt.legend(title='Meilleure Année', bbox_to_anchor=(1.05, 1), loc='upper left')

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}', 
        (p.get_x() + p.get_width() / 2., p.get_height()), 
        ha='center', 
        va='bottom',
        fontsize=10,
        xytext=(0, 5),
        textcoords='offset points'
    )


plt.tight_layout()
plt.show()

# %% [markdown]
# * Les années où le taux de croissance est le plus élevé sont bien celles du précédent graphique.

# %% [markdown]
# ## Données en .CSV

# %%
#Téléchargement des tables facts en .csv avant la fin de la période d'essai sur SNOWFLAKE et DBT
fct_croissance.to_csv("fct_croissance.csv",index=False)
fct_airlines.to_csv("fct_airlines.csv",index=False)
fct_airports.to_csv("fct_airports.csv",index=False)
fct_croissance_per_year.to_csv("fct_croissance_per_year.csv",index=False)
fct_number_of_flights.to_csv("fct_number_of_flights.csv",index=False)

# %%
#Téléchargement des tables dimensions en .csv avant la fin de la période d'essai sur SNOWFLAKE et DBT 
dim_aircraft.to_csv("dim_aircraft.csv",index=False)
dim_airlines.to_csv("dim_airlines.csv",index=False)
dim_airports.to_csv("dim_airports.csv",index=False)
dim_flight_summary_data.to_csv("dim_flight_summary_data.csv",index=False)
dim_individual_flights.to_csv("dim_individual_flights.csv",index=False)

# %%
#Téléchargement des staging en .csv avant la fin de la période d'essai sur SNOWFLAKE et DBT
stg_aircraft.to_csv("stg_aircraft.csv",index=False)
stg_airlines.to_csv("stg_airlines.csv",index=False)
stg_airports.to_csv("stg_airports.csv",index=False)
stg_flight_summary_data.to_csv("stg_flight_summary_data.csv",index=False)
stg_individual_flights.to_csv("stg_individual_flights.csv",index=False)
